# %%
from bs4 import BeautifulSoup as bs4

# %%
import requests as req

# %%
import time

# %%
url = "https://ww5.dubbedanime.net/anime/3852-kaguya-sama-love-is-war"

# %%
data = req.get(url)

# %%
data
# Out:
# <Response [200]>

# %%
data = data.text

# %%
soup = bs4(data,'html.parser')

# %%
div = soup.find_all("div",{"class":"da-video-tbl"})

# %%
print(div[1].a['href'])
# Out:
# /episode/189837-kaguya-sama-love-is-war-episode-11

# %%
eps = []

# %%
for ele in div:
    eps.append("https://ww5.dubbedanime.net" + ele.a['href'] + "-english-sub")

# %%
eps.sort()

# %%
eps
# Out:
# ['https://ww5.dubbedanime.net/episode/188010-kaguya-sama-love-is-war-episode-1-english-sub',
#  'https://ww5.dubbedanime.net/episode/188098-kaguya-sama-love-is-war-episode-2-english-sub',
#  'https://ww5.dubbedanime.net/episode/188642-kaguya-sama-love-is-war-episode-3-english-sub',
#  'https://ww5.dubbedanime.net/episode/188869-kaguya-sama-love-is-war-episode-4-english-sub',
#  'https://ww5.dubbedanime.net/episode/189051-kaguya-sama-love-is-war-episode-5-english-sub',
#  'https://ww5.dubbedanime.net/episode/189227-kaguya-sama-love-is-war-episode-6-english-sub',
#  'https://ww5.dubbedanime.net/episode/189337-kaguya-sama-love-is-war-episode-7-english-sub',
#  'https://ww5.dubbedanime.net/episode/189458-kaguya-sama-love-is-war-episode-8-english-sub',
#  'https://ww5.dubbedanime.net/episode/189592-kaguya-sama-love-is-war-episode-9-english-sub',
#  'https://ww5.dubbedanime.net/episode/189755-kaguya-sama-love-is-war-episode-10-english-sub',
# ...

# %%
ep_url = eps[0]

# %%
ep_data = req.get(ep_url)

# %%
ep_data = ep_data.text

# %%
ep_soup = bs4(ep_data,'html.parser')

# %%
video = ep_soup.find_all('video')

# %%
video
# Out:
# []

# %%
ep_soup.prettify()
# Out:
# '<!DOCTYPE doctype html>\n<html lang="en">\n <head>\n  <title>\n   Kaguya-sama: Love is War Episode 1 English Sub | Dubbed Anime\n  </title>\n  <meta charset="utf-8"/>\n  <meta content="Anime, Cartoon, TV" name="classification">\n   <meta content="General" name="rating"/>\n   <meta content="global" name="distribution"/>\n   <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=0" name="viewport"/>\n   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>\n   <meta content="Watch Kaguya-sama: Love is War Episode 1 English Sub. Stream Kaguya-sama: Love is War Episode 1 English Sub online for free! Kaguya-sama: Love is War Episode 1" name="description"/>\n   <meta content="index, follow" name="robots">\n    <meta content="index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1" name="googlebot"/>\n    <meta content="index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1" name="bingbot"/>\n    <link href="https:
# ...

# %%
ep_soup
# Out:
# <!DOCTYPE doctype html>
#
# <html lang="en">
# <head>
# <title>Kaguya-sama: Love is War Episode 1 English Sub | Dubbed Anime</title>
# <meta charset="utf-8"/>
# <meta content="Anime, Cartoon, TV" name="classification">
# <meta content="General" name="rating"/>
# <meta content="global" name="distribution"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=0" name="viewport"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="Watch Kaguya-sama: Love is War Episode 1 English Sub. Stream Kaguya-sama: Love is War Episode 1 English Sub online for free! Kaguya-sama: Love is War Episode 1" name="description"/>
# <meta content="index, follow" name="robots">
# <meta content="index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1" name="googlebot"/>
# <meta content="index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1" name="bingbot"/>
# ...

# %%
html = req.get(ep_url,time.sleep(10)).text

# %%
s = bs4(html,'html.parser')

# %%
s
# Out:
# <!DOCTYPE doctype html>
#
# <html lang="en">
# <head>
# <title>Kaguya-sama: Love is War Episode 1 English Sub | Dubbed Anime</title>
# <meta charset="utf-8"/>
# <meta content="Anime, Cartoon, TV" name="classification">
# <meta content="General" name="rating"/>
# <meta content="global" name="distribution"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=0" name="viewport"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="Watch Kaguya-sama: Love is War Episode 1 English Sub. Stream Kaguya-sama: Love is War Episode 1 English Sub online for free! Kaguya-sama: Love is War Episode 1" name="description"/>
# <meta content="index, follow" name="robots">
# <meta content="index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1" name="googlebot"/>
# <meta content="index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1" name="bingbot"/>
# ...
