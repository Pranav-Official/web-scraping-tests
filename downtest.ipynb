# %%
import selenium
from selenium import webdriver as wd
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.chrome.options import Options



#prefs = {"download.default_directory": down_dir}
#chrome_options.add_experimental_option('prefs', prefs)

chrome_options = Options()
chrome_options.add_argument("--allow-multiple-downloads")
#chrome_options.add_extension('/home/pranavhtjp07/Desktop/pranavhtjp07/ada/aria2c.crx')
chrome_options.add_experimental_option("prefs", {
        "download.prompt_for_download": False,
        "download.directory_upgrade": True,
        "safebrowsing_for_trusted_sources_enabled": False,
        "safebrowsing.enabled": False
})

driver_path = "/usr/bin/chromedriver"
driver = wd.Chrome(driver_path, options=chrome_options)

url = "https://ww5.dubbedanime.net/episode/202195-the-god-of-high-school-episode-6-english-dub"

driver.get(url)

# %%
import json

# %%
from browsermobproxy import Server
server = Server("/home/pranavhtjp07/Desktop/browsermob-proxy-2.1.4/bin/browsermob-proxy", options={"port": 8090})
server.start()
proxy = server.create_proxy()

# %%
import time

# %%
def Login():
    #try:
     #   driver.find_element_by_xpath("/html/body/nav/div/div[2]/ul/li[7]/a").click()
    #except:
     #   driver.find_element_by_xpath("/html/body/nav/div/div[1]/button").click()
     #   time.sleep(1)
     #   driver.find_element_by_xpath("/html/body/nav/div/div[2]/ul/li[7]/a").click()
        
    usename_filed = driver.find_element_by_id("login-username")
    password_filed = driver.find_element_by_id("login-password")
    usename_filed.send_keys("KakashiHatake")
    password_filed.send_keys("Z3#!wvSwkS8rkd$")
    login_button = driver.find_element_by_xpath("/html/body/div[2]/div/div/form/button")
    login_button.click()

# %%
def download():
    button = driver.find_element_by_id("download-video")
    button.click()
    for i in range(10):
        print(driver.current_url)

# %%
download()

for i in range(10):
    print(driver.current_url)

# %%
Login()

for i in range(10):
    print(driver.current_url)

# %%
import requests
from bs4 import BeautifulSoup as bs

# %%
url = "https://ww5.dubbedanime.net/episode/202156-deca-dence-episode-5-english-dub"
video = "https://s2.mp4.sh/d/9e60d49661d3.mp4?st=MBifxhRZc8s0d_vtLVRK4g&e=1601610181"

# %%
html = requests.get(url)

# %%
soup = bs(html,"html.parser").prettify()

# %%
driver.get(url);
time.sleep(10)
timings = driver.execute_script("return window.performance.getEntries();")
print(timings)

# %%
#chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument("--proxy-server={0}".format(proxy.proxy))
chrome_options.add_argument("--ignore-certificate-errors")
browser = wd.Chrome(options = chrome_options)

# %%
proxy.new_har("low")
# Out:
# (200,
#  {'log': {'version': '1.2',
#    'creator': {'name': 'BrowserMob Proxy', 'version': '2.1.4', 'comment': ''},
#    'pages': [{'id': 'low',
#      'startedDateTime': '2020-10-01T14:33:59.380+05:30',
#      'title': 'low',
#      'pageTimings': {'onLoad': 103223, 'comment': ''},
#      'comment': ''}],
#    'entries': [{'pageref': 'low',
#      'startedDateTime': '2020-10-01T14:34:00.230+05:30',
#      'request': {'method': 'POST',
#       'url': 'https://mp4.sh/cdn-cgi/bm/cv/result?req_id=5db5033ddcdfd9b4',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'queryString': [{'name': 'req_id', 'value': '5db5033ddcdfd9b4'}],
#       'headersSize': 883,
#       'bodySize': 701,
#       'comment': ''},
#      'response': {'status': 204,
#       'statusText': 'No Content',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'content': {'size': 0, 'mimeType': '', 'comment': ''},
#       'redirectURL': '',
#       'headersSize': 977,
#       'bodySize': 0,
#       'comment': ''},
#      'cache': {},
#      'timings': {'comment': '',
#       'blocked': -1,
#       'dns': -1,
#       'connect': -1,
#       'send': 0,
#       'wait': 134,
#       'receive': 0,
#       'ssl': -1},
#      'serverIPAddress': '172.67.143.85',
#      'comment': '',
#      'time': 134},
#     {'pageref': 'low',
#      'startedDateTime': '2020-10-01T14:34:00.237+05:30',
#      'request': {'method': 'POST',
#       'url': 'https://mp4.sh/v/6a190390b36d',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'queryString': [],
#       'headersSize': 870,
#       'bodySize': 269,
#       'comment': ''},
#      'response': {'status': 200,
#       'statusText': 'OK',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'content': {'size': 0, 'mimeType': 'application/json', 'comment': ''},
#       'redirectURL': '',
#       'headersSize': 729,
#       'bodySize': 102,
#       'comment': ''},
#      'cache': {},
#      'timings': {'comment': '',
#       'blocked': -1,
#       'dns': -1,
#       'connect': -1,
#       'send': 0,
#       'wait': 620,
#       'receive': 0,
#       'ssl': -1},
#      'serverIPAddress': '172.67.143.85',
#      'comment': '',
#      'time': 620},
#     {'pageref': 'low',
#      'startedDateTime': '2020-10-01T14:34:00.248+05:30',
#      'request': {'method': 'GET',
#       'url': 'https://mp4.sh/images/ripple.svg',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'queryString': [],
#       'headersSize': 817,
#       'bodySize': 0,
#       'comment': ''},
#      'response': {'status': 200,
#       'statusText': 'OK',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'content': {'size': 0, 'mimeType': 'image/svg+xml', 'comment': ''},
#       'redirectURL': '',
#       'headersSize': 856,
#       'bodySize': 337,
#       'comment': ''},
#      'cache': {},
#      'timings': {'comment': '',
#       'blocked': -1,
#       'dns': -1,
#       'connect': -1,
#       'send': 0,
#       'wait': 160,
#       'receive': 0,
#       'ssl': -1},
#      'serverIPAddress': '172.67.143.85',
#      'comment': '',
#      'time': 160},
#     {'pageref': 'low',
#      'startedDateTime': '2020-10-01T14:34:00.243+05:30',
#      'request': {'method': 'CONNECT',
#       'url': 'https://r.remarketingpixel.com',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'queryString': [],
#       'headersSize': 0,
#       'bodySize': 0,
#       'comment': ''},
#      'response': {'status': 0,
#       'statusText': '',
#       'httpVersion': 'unknown',
#       'cookies': [],
#       'headers': [],
#       'content': {'size': 0, 'mimeType': '', 'comment': ''},
#       'redirectURL': '',
#       'headersSize': -1,
#       'bodySize': -1,
#       'comment': '',
#       '_error': 'Unable to connect to host'},
#      'cache': {},
#      'timings': {'comment': '',
#       'blocked': 0,
#       'dns': 9,
#       'connect': 0,
#       'send': 0,
#       'wait': 0,
#       'receive': 0,
#       'ssl': -1},
#      'serverIPAddress': '0.0.0.0',
#      'comment': '',
#      'time': 10},
#     {'pageref': 'low',
#      'startedDateTime': '2020-10-01T14:34:00.422+05:30',
#      'request': {'method': 'CONNECT',
#       'url': 'https://r.remarketingpixel.com',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'queryString': [],
#       'headersSize': 0,
#       'bodySize': 0,
#       'comment': ''},
#      'response': {'status': 0,
#       'statusText': '',
#       'httpVersion': 'unknown',
#       'cookies': [],
#       'headers': [],
#       'content': {'size': 0, 'mimeType': '', 'comment': ''},
#       'redirectURL': '',
#       'headersSize': -1,
#       'bodySize': -1,
#       'comment': '',
#       '_error': 'Unable to connect to host'},
#      'cache': {},
#      'timings': {'comment': '',
#       'blocked': 0,
#       'dns': 0,
#       'connect': 2,
#       'send': 0,
#       'wait': 0,
#       'receive': 0,
#       'ssl': -1},
#      'serverIPAddress': '0.0.0.0',
#      'comment': '',
#      'time': 2},
#     {'pageref': 'low',
#      'startedDateTime': '2020-10-01T14:34:01.813+05:30',
#      'request': {'method': 'GET',
#       'url': 'https://d24ak3f2b.top/advertisers.js',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'queryString': [],
#       'headersSize': 612,
#       'bodySize': 0,
#       'comment': ''},
#      'response': {'status': 200,
#       'statusText': 'OK',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'content': {'size': 0,
#        'mimeType': 'application/javascript',
#        'comment': ''},
#       'redirectURL': '',
#       'headersSize': 161,
#       'bodySize': 0,
#       'comment': ''},
#      'cache': {},
#      'timings': {'comment': '',
#       'blocked': 0,
#       'dns': 4,
#       'connect': 1357,
#       'send': 0,
#       'wait': 314,
#       'receive': 0,
#       'ssl': 954},
#      'serverIPAddress': '64.58.113.244',
#      'comment': '',
#      'time': 1676},
#     {'pageref': 'low',
#      'startedDateTime': '2020-10-01T14:34:02.536+05:30',
#      'request': {'method': 'CONNECT',
#       'url': 'https://nbf9b5aurl.com',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'queryString': [],
#       'headersSize': 0,
#       'bodySize': 0,
#       'comment': ''},
#      'response': {'status': 0,
#       'statusText': '',
#       'httpVersion': 'unknown',
#       'cookies': [],
#       'headers': [],
#       'content': {'size': 0, 'mimeType': '', 'comment': ''},
#       'redirectURL': '',
#       'headersSize': -1,
#       'bodySize': -1,
#       'comment': '',
#       '_error': 'Unable to connect to host'},
#      'cache': {},
#      'timings': {'comment': '',
#       'blocked': 0,
#       'dns': 8,
#       'connect': 0,
#       'send': 0,
#       'wait': 0,
#       'receive': 0,
#       'ssl': -1},
#      'serverIPAddress': '0.0.0.0',
#      'comment': '',
#      'time': 8},
#     {'pageref': 'low',
#      'startedDateTime': '2020-10-01T14:34:03.664+05:30',
#      'request': {'method': 'GET',
#       'url': 'https://s1.mp4.sh/d/6a190390b36d.mp4?st=jyeunwx5X2GEvirdXyMp_g&e=1601629440',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'queryString': [{'name': 'st', 'value': 'jyeunwx5X2GEvirdXyMp_g'},
#        {'name': 'e', 'value': '1601629440'}],
#       'headersSize': 949,
#       'bodySize': 0,
#       'comment': ''},
#      'response': {'status': 206,
#       'statusText': 'Partial Content',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'content': {'size': 0, 'mimeType': 'video/mp4', 'comment': ''},
#       'redirectURL': '',
#       'headersSize': 294,
#       'bodySize': -1,
#       'comment': ''},
#      'cache': {},
#      'timings': {'comment': '',
#       'blocked': 0,
#       'dns': 9,
#       'connect': 1089,
#       'send': 0,
#       'wait': 436,
#       'receive': 5476,
#       'ssl': 576},
#      'serverIPAddress': '217.182.198.170',
#      'comment': '',
#      'time': 7012},
#     {'pageref': 'low',
#      'startedDateTime': '2020-10-01T14:34:10.313+05:30',
#      'request': {'method': 'GET',
#       'url': 'https://insectadvertisesecretly.com/sbar.json?key=930e98122e1841c8112ab29dda9e4a67',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'queryString': [{'name': 'key',
#         'value': '930e98122e1841c8112ab29dda9e4a67'}],
#       'headersSize': 678,
#       'bodySize': 0,
#       'comment': ''},
#      'response': {'status': 200,
#       'statusText': 'OK',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'content': {'size': 0,
#        'mimeType': 'text/plain; charset=utf-8',
#        'comment': ''},
#       'redirectURL': '',
#       'headersSize': 929,
#       'bodySize': 2223,
#       'comment': ''},
#      'cache': {},
#      'timings': {'comment': '',
#       'blocked': 0,
#       'dns': 90,
#       'connect': 975,
#       'send': 0,
#       'wait': 459,
#       'receive': 0,
#       'ssl': 704},
#      'serverIPAddress': '192.243.59.20',
#      'comment': '',
#      'time': 1525},
#     {'pageref': 'low',
#      'startedDateTime': '2020-10-01T14:34:11.314+05:30',
#      'request': {'method': 'GET',
#       'url': 'https://socialbars-web2.com/sb/notifications/addon/websecurerr/mac/2/index.html',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'queryString': [],
#       'headersSize': 675,
#       'bodySize': 0,
#       'comment': ''},
#      'response': {'status': 200,
#       'statusText': 'OK',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'content': {'size': 0, 'mimeType': 'text/html', 'comment': ''},
#       'redirectURL': '',
#       'headersSize': 918,
#       'bodySize': 420,
#       'comment': ''},
#      'cache': {},
#      'timings': {'comment': '',
#       'blocked': 0,
#       'dns': 94,
#       'connect': 435,
#       'send': 0,
#       'wait': 330,
#       'receive': 0,
#       'ssl': 233},
#      'serverIPAddress': '172.64.140.24',
#      'comment': '',
#      'time': 860},
#     {'pageref': 'low',
#      'startedDateTime': '2020-10-01T14:34:11.764+05:30',
#      'request': {'method': 'GET',
#       'url': 'https://fonts.googleapis.com/css?family=Roboto:300,400,700&display=swap',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'queryString': [{'name': 'family', 'value': 'Roboto:300,400,700'},
#        {'name': 'display', 'value': 'swap'}],
#       'headersSize': 417,
#       'bodySize': 0,
#       'comment': ''},
#      'response': {'status': 200,
#       'statusText': 'OK',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'content': {'size': 0,
#        'mimeType': 'text/css; charset=utf-8',
#        'comment': ''},
#       'redirectURL': '',
#       'headersSize': 796,
#       'bodySize': 700,
#       'comment': ''},
#      'cache': {},
#      'timings': {'comment': '',
#       'blocked': -1,
#       'dns': -1,
#       'connect': -1,
#       'send': 0,
#       'wait': 97,
#       'receive': 0,
#       'ssl': -1},
#      'serverIPAddress': '172.217.31.202',
#      'comment': '',
#      'time': 98},
#     {'pageref': 'low',
#      'startedDateTime': '2020-10-01T14:34:11.937+05:30',
#      'request': {'method': 'GET',
#       'url': 'https://socialbars-web4.com/sb/notifications/addon/websecurerr/mac/2/css/animate.css',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'queryString': [],
#       'headersSize': 680,
#       'bodySize': 0,
#       'comment': ''},
#      'response': {'status': 200,
#       'statusText': 'OK',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'content': {'size': 0, 'mimeType': 'text/css', 'comment': ''},
#       'redirectURL': '',
#       'headersSize': 961,
#       'bodySize': 4343,
#       'comment': ''},
#      'cache': {},
#      'timings': {'comment': '',
#       'blocked': 0,
#       'dns': 66,
#       'connect': 210,
#       'send': 0,
#       'wait': 118,
#       'receive': 22,
#       'ssl': 131},
#      'serverIPAddress': '104.31.72.112',
#      'comment': '',
#      'time': 417},
#     {'pageref': 'low',
#      'startedDateTime': '2020-10-01T14:34:11.938+05:30',
#      'request': {'method': 'GET',
#       'url': 'https://socialbars-web4.com/sb/notifications/addon/websecurerr/mac/2/css/style.css',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'queryString': [],
#       'headersSize': 678,
#       'bodySize': 0,
#       'comment': ''},
#      'response': {'status': 200,
#       'statusText': 'OK',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'content': {'size': 0, 'mimeType': 'text/css', 'comment': ''},
#       'redirectURL': '',
#       'headersSize': 959,
#       'bodySize': 1005,
#       'comment': ''},
#      'cache': {},
#      'timings': {'comment': '',
#       'blocked': 0,
#       'dns': 66,
#       'connect': 211,
#       'send': 0,
#       'wait': 139,
#       'receive': 0,
#       'ssl': 125},
#      'serverIPAddress': '104.31.72.112',
#      'comment': '',
#      'time': 417},
#     {'pageref': 'low',
#      'startedDateTime': '2020-10-01T14:34:11.941+05:30',
#      'request': {'method': 'GET',
#       'url': 'https://socialbars-web4.com/sb/notifications/addon/websecurerr/mac/2/js/script.js',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'queryString': [],
#       'headersSize': 677,
#       'bodySize': 0,
#       'comment': ''},
#      'response': {'status': 200,
#       'statusText': 'OK',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'content': {'size': 0,
#        'mimeType': 'application/javascript',
#        'comment': ''},
#       'redirectURL': '',
#       'headersSize': 973,
#       'bodySize': 239,
#       'comment': ''},
#      'cache': {},
#      'timings': {'comment': '',
#       'blocked': 0,
#       'dns': 65,
#       'connect': 214,
#       'send': 0,
#       'wait': 156,
#       'receive': 0,
#       'ssl': 127},
#      'serverIPAddress': '104.31.72.112',
#      'comment': '',
#      'time': 436},
#     {'pageref': 'low',
#      'startedDateTime': '2020-10-01T14:34:11.994+05:30',
#      'request': {'method': 'GET',
#       'url': 'https://socialbars-web4.com/sb/notifications/addon/websecurerr/mac/2/img/update-icon.png',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'queryString': [],
#       'headersSize': 455,
#       'bodySize': 0,
#       'comment': ''},
#      'response': {'status': 200,
#       'statusText': 'OK',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'content': {'size': 0, 'mimeType': 'image/png', 'comment': ''},
#       'redirectURL': '',
#       'headersSize': 954,
#       'bodySize': 26989,
#       'comment': ''},
#      'cache': {},
#      'timings': {'comment': '',
#       'blocked': 0,
#       'dns': 0,
#       'connect': 224,
#       'send': 0,
#       'wait': 115,
#       'receive': 15,
#       'ssl': 130},
#      'serverIPAddress': '104.31.72.112',
#      'comment': '',
#      'time': 355},
#     {'pageref': 'low',
#      'startedDateTime': '2020-10-01T14:34:11.996+05:30',
#      'request': {'method': 'GET',
#       'url': 'https://socialbars-web4.com/sb/notifications/addon/websecurerr/mac/2/img/close.svg',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'queryString': [],
#       'headersSize': 449,
#       'bodySize': 0,
#       'comment': ''},
#      'response': {'status': 200,
#       'statusText': 'OK',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'content': {'size': 0, 'mimeType': 'image/svg+xml', 'comment': ''},
#       'redirectURL': '',
#       'headersSize':

#       'receive': 0,
#       'ssl': -1},
#      'serverIPAddress': '192.243.59.20',
#      'comment': '',
#      'time': 577},
#     {'pageref': 'low',
#      'startedDateTime': '2020-10-01T14:34:47.113+05:30',
#      'request': {'method': 'POST',
#       'url': 'https://update.googleapis.com/service/update2/json?cup2key=10:1140432913&cup2hreq=4c2baeb07a16bab6c3f53e621b1b606ea7e940314dc2c70ae50583c0f618a7d3',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'queryString': [{'name': 'cup2key', 'value': '10:1140432913'},
#        {'name': 'cup2hreq',
#         'value': '4c2baeb07a16bab6c3f53e621b1b606ea7e940314dc2c70ae50583c0f618a7d3'}],
#       'headersSize': 1029,
#       'bodySize': 2007,
#       'comment': ''},
#      'response': {'status': 200,
#       'statusText': 'OK',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'content': {'size': 0,
#        'mimeType': 'application/json; charset=utf-8',
#        'comment': ''},
#       'redirectURL': '',
#       'headersSize': 1327,
#       'bodySize': 2504,
#       'comment': ''},
#      'cache': {},
#      'timings': {'comment': '',
#       'blocked': 0,
#       'dns': 5043,
#       'connect': 133,
#       'send': 0,
#       'wait': 326,
#       'receive': 11,
#       'ssl': 80},
#      'serverIPAddress': '216.58.197.35',
#      'comment': '',
#      'time': 5515},
#     {'pageref': 'low',
#      'startedDateTime': '2020-10-01T14:34:47.461+05:30',
#      'request': {'method': 'GET',
#       'url': 'http://redirector.gvt1.com/edgedl/release2/chrome_component/PUBwS76-dbWSH_MgHoAg0w_32.0.0.433/AJqxA4yJ_sTuoc28Xr1Cnd0',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'queryString': [],
#       'headersSize': 343,
#       'bodySize': 0,
#       'comment': ''},
#      'response': {'status': 302,
#       'statusText': 'Found',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'content': {'size': 0,
#        'mimeType': 'text/html; charset=UTF-8',
#        'comment': ''},
#       'redirectURL': 'http://r2---sn-gwpa-jv3l.gvt1.com/edgedl/release2/chrome_component/PUBwS76-dbWSH_MgHoAg0w_32.0.0.433/AJqxA4yJ_sTuoc28Xr1Cnd0?cms_redirect=yes&mh=7A&mip=157.44.154.115&mm=28&mn=sn-gwpa-jv3l&ms=nvh&mt=1601542934&mv=m&mvi=2&pl=19&shardbypass=yes',
#       'headersSize': 551,
#       'bodySize': 479,
#       'comment': ''},
#      'cache': {},
#      'timings': {'comment': '',
#       'blocked': 0,
#       'dns': 87,
#       'connect': 40,
#       'send': 0,
#       'wait': 102,
#       'receive': 0,
#       'ssl': -1},
#      'serverIPAddress': '172.217.160.142',
#      'comment': '',
#      'time': 230},
#     {'pageref': 'low',
#      'startedDateTime': '2020-10-01T14:34:47.694+05:30',
#      'request': {'method': 'GET',
#       'url': 'http://r2---sn-gwpa-jv3l.gvt1.com/edgedl/release2/chrome_component/PUBwS76-dbWSH_MgHoAg0w_32.0.0.433/AJqxA4yJ_sTuoc28Xr1Cnd0?cms_redirect=yes&mh=7A&mip=157.44.154.115&mm=28&mn=sn-gwpa-jv3l&ms=nvh&mt=1601542934&mv=m&mvi=2&pl=19&shardbypass=yes',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'queryString': [{'name': 'cms_redirect', 'value': 'yes'},
#        {'name': 'mh', 'value': '7A'},
#        {'name': 'mip', 'value': '157.44.154.115'},
#        {'name': 'mm', 'value': '28'},
#        {'name': 'mn', 'value': 'sn-gwpa-jv3l'},
#        {'name': 'ms', 'value': 'nvh'},
#        {'name': 'mt', 'value': '1601542934'},
#        {'name': 'mv', 'value': 'm'},
#        {'name': 'mvi', 'value': '2'},
#        {'name': 'pl', 'value': '19'},
#        {'name': 'shardbypass', 'value': 'yes'}],
#       'headersSize': 475,
#       'bodySize': 0,
#       'comment': ''},
#      'response': {'status': 200,
#       'statusText': 'OK',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'content': {'size': 0,
#        'mimeType': 'application/octet-stream',
#        'comment': ''},
#       'redirectURL': '',
#       'headersSize': 650,
#       'bodySize': 7211238,
#       'comment': ''},
#      'cache': {},
#      'timings': {'comment': '',
#       'blocked': 0,
#       'dns': 85,
#       'connect': 37,
#       'send': 0,
#       'wait': 278,
#       'receive': 15192,
#       'ssl': -1},
#      'serverIPAddress': '49.44.84.237',
#      'comment': '',
#      'time': 15593},
#     {'pageref': 'low',
#      'startedDateTime': '2020-10-01T14:35:03.588+05:30',
#      'request': {'method': 'POST',
#       'url': 'https://update.googleapis.com/service/update2/json',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'queryString': [],
#       'headersSize': 371,
#       'bodySize': 962,
#       'comment': ''},
#      'response': {'status': 200,
#       'statusText': 'OK',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'content': {'size': 0,
#        'mimeType': 'application/json; charset=utf-8',
#        'comment': ''},
#       'redirectURL': '',
#       'headersSize': 875,
#       'bodySize': 171,
#       'comment': ''},
#      'cache': {},
#      'timings': {'comment': '',
#       'blocked': -1,
#       'dns': -1,
#       'connect': -1,
#       'send': 0,
#       'wait': 252,
#       'receive': 0,
#       'ssl': -1},
#      'serverIPAddress': '216.58.197.35',
#      'comment': '',
#      'time': 253},
#     {'pageref': 'low',
#      'startedDateTime': '2020-10-01T14:35:19.721+05:30',
#      'request': {'method': 'GET',
#       'url': 'http://redirector.gvt1.com/edgedl/chromewebstore/L2Nocm9tZV9leHRlbnNpb24vYmxvYnMvYjFkQUFWdmlaXy12MHFUTGhWQUViMUVlUQ/0.57.44.2492_hnimpnehoodheedghdeeijklkeaacbdc.crx',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'queryString': [],
#       'headersSize': 391,
#       'bodySize': 0,
#       'comment': ''},
#      'response': {'status': 302,
#       'statusText': 'Found',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'content': {'size': 0,
#        'mimeType': 'text/html; charset=UTF-8',
#        'comment': ''},
#       'redirectURL': 'http://r6---sn-gwpa-jv3e.gvt1.com/edgedl/chromewebstore/L2Nocm9tZV9leHRlbnNpb24vYmxvYnMvYjFkQUFWdmlaXy12MHFUTGhWQUViMUVlUQ/0.57.44.2492_hnimpnehoodheedghdeeijklkeaacbdc.crx?cms_redirect=yes&mh=2D&mip=157.44.154.115&mm=28&mn=sn-gwpa-jv3e&ms=nvh&mt=1601542934&mv=m&mvi=6&pcm2cms=yes&pl=19&shardbypass=yes',
#       'headersSize': 611,
#       'bodySize': 543,
#       'comment': ''},
#      'cache': {},
#      'timings': {'comment': '',
#       'blocked': -1,
#       'dns': -1,
#       'connect': -1,
#       'send': 0,
#       'wait': 137,
#       'receive': 0,
#       'ssl': -1},
#      'serverIPAddress': '172.217.160.142',
#      'comment': '',
#      'time': 137},
#     {'pageref': 'low',
#      'startedDateTime': '2020-10-01T14:35:19.864+05:30',
#      'request': {'method': 'GET',
#       'url': 'http://r6---sn-gwpa-jv3e.gvt1.com/edgedl/chromewebstore/L2Nocm9tZV9leHRlbnNpb24vYmxvYnMvYjFkQUFWdmlaXy12MHFUTGhWQUViMUVlUQ/0.57.44.2492_hnimpnehoodheedghdeeijklkeaacbdc.crx?cms_redirect=yes&mh=2D&mip=157.44.154.115&mm=28&mn=sn-gwpa-jv3e&ms=nvh&mt=1601542934&mv=m&mvi=6&pcm2cms=yes&pl=19&shardbypass=yes',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'queryString': [{'name': 'cms_redirect', 'value': 'yes'},
#        {'name': 'mh', 'value': '2D'},
#        {'name': 'mip', 'value': '157.44.154.115'},
#        {'name': 'mm', 'value': '28'},
#        {'name': 'mn', 'value': 'sn-gwpa-jv3e'},
#        {'name': 'ms', 'value': 'nvh'},
#        {'name': 'mt', 'value': '1601542934'},
#        {'name': 'mv', 'value': 'm'},
#        {'name': 'mvi', 'value': '6'},
#        {'name': 'pcm2cms', 'value': 'yes'},
#        {'name': 'pl', 'value': '19'},
#        {'name': 'shardbypass', 'value': 'yes'}],
#       'headersSize': 535,
#       'bodySize': 0,
#       'comment': ''},
#      'response': {'status': 200,
#       'statusText': 'OK',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'content': {'size': 0,
#        'mimeType': 'application/x-chrome-extension',
#        'comment': ''},
#       'redirectURL': '',
#       'headersSize': 656,
#       'bodySize': 6760942,
#       'comment': ''},
#      'cache': {},
#      'timings': {'comment': '',
#       'blocked': 0,
#       'dns': 56,
#       'connect': 36,
#       'send': 0,
#       'wait': 96,
#       'receive': 13553,
#       'ssl': -1},
#      'serverIPAddress': '49.44.84.209',
#      'comment': '',
#      'time': 13742},
#     {'pageref': 'low',
#      'startedDateTime': '2020-10-01T14:35:33.820+05:30',
#      'request': {'method': 'POST',
#       'url': 'https://update.googleapis.com/service/update2/json',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'queryString': [],
#       'headersSize': 372,
#       'bodySize': 1016,
#       'comment': ''},
#      'response': {'status': 200,
#       'statusText': 'OK',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'content': {'size': 0,
#        'mimeType': 'application/json; charset=utf-8',
#        'comment': ''},
#       'redirectURL': '',
#       'headersSize': 875,
#       'bodySize': 168,
#       'comment': ''},
#      'cache': {},
#      'timings': {'comment': '',
#       'blocked': -1,
#       'dns': -1,
#       'connect': -1,
#       'send': 0,
#       'wait': 266,
#       'receive': 0,
#       'ssl': -1},
#      'serverIPAddress': '216.58.197.35',
#      'comment': '',
#      'time': 267},
#     {'pageref': 'low',
#      'startedDateTime': '2020-10-01T14:35:37.366+05:30',
#      'request': {'method': 'GET',
#       'url': 'https://ww5.dubbedanime.net/episode/202156-deca-dence-episode-5-english-dub',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'queryString': [],
#       'headersSize': 688,
#       'bodySize': 0,
#       'comment': ''},
#      'response': {'status': 200,
#       'statusText': 'OK',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'content': {'size': 0,
#        'mimeType': 'text/html; charset=UTF-8',
#        'comment': ''},
#       'redirectURL': '',
#       'headersSize': 588,
#       'bodySize': 4690,
#       'comment': ''},
#      'cache': {},
#      'timings': {'comment': '',
#       'blocked': -1,
#       'dns': -1,
#       'connect': -1,
#       'send': 0,
#       'wait': 314,
#       'receive': 3,
#       'ssl': -1},
#      'serverIPAddress': '104.26.6.22',
#      'comment': '',
#      'time': 317},
#     {'pageref': 'low',
#      'startedDateTime': '2020-10-01T14:35:37.366+05:30',
#      'request': {'method': 'CONNECT',
#       'url': 'https://platform.bidgear.com',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'queryString': [],
#       'headersSize': 0,
#       'bodySize': 0,
#       'comment': ''},
#      'response': {'status': 0,
#       'statusText': '',
#       'httpVersion': 'unknown',
#       'cookies': [],
#       'headers': [],
#       'content': {'size': 0, 'mimeType': '', 'comment': ''},
#       'redirectURL': '',
#       'headersSize': -1,
#       'bodySize': -1,
#       'comment': '',
#       '_error': 'Unable to connect to host'},
#      'cache': {},
#      'timings': {'comment': '',
#       'blocked': 0,
#       'dns': 82,
#       'connect': 2,
#       'send': 0,
#       'wait': 0,
#       'receive': 0,
#       'ssl': -1},
#      'serverIPAddress': '0.0.0.0',
#      'comment': '',
#      'time': 84},
#     {'pageref': 'low',
#      'startedDateTime': '2020-10-01T14:35:37.366+05:30',
#      'request': {'method': 'CONNECT',
#       'url': 'https://www.googletagmanager.com',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'queryString': [],
#       'headersSize': 0,
#       'bodySize': 0,
#       'comment': ''},
#      'response': {'status': 0,
#       'statusText': '',
#       'httpVersion': 'unknown',
#       'cookies': [],
#       'headers': [],
#       'content': {'size': 0, 'mimeType': '', 'comment': ''},
#       'redirectURL': '',
#       'headersSize': -1,
#       'bodySize': -1,
#       'comment': '',
#       '_error': 'Unable to connect to host'},
#      'cache': {},
#      'timings': {'comment': '',
#       'blocked': 0,
#       'dns': 83,
#       'connect': 2,
#       'send': 0,
#       'wait': 0,
#       'receive': 0,
#       'ssl': -1},
#      'serverIPAddress': '0.0.0.0',
#      'comment': '',
#      'time': 85},
#     {'pageref': 'low',
#      'startedDateTime': '2020-10-01T14:35:37.776+05:30',
#      'request': {'method': 'CONNECT',
#       'url': 'https://platform.bidgear.com',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'queryString': [],
#       'headersSize': 0,
#       'bodySize': 0,
#       'comment': ''},
#      'response': {'status': 0,
#       'statusText': '',
#       'httpVersion': 'unknown',
#       'cookies': [],
#       'headers': [],
#       'content': {'size': 0, 'mimeType': '', 'comment': ''},
#       'redirectURL': '',
#       'headersSize': -1,
#       'bodySize': -1,
#       'comment': '',
#       '_error': 'Unable to connect to host'},
#      'cache': {},
#      'timings': {'comment': '',
#       'blocked': 0,
#       'dns': 0,
#       'connect': 1,
#       'send': 0,
#       'wait': 0,
#       'receive': 0,
#       'ssl': -1},
#      'serverIPAddress': '0.0.0.0',
#      'comment': '',
#      'time': 1},
#     {'pageref': 'low',
#      'startedDateTime': '2020-10-01T14:35:37.776+05:30',
#      'request': {'method': 'CONNECT',
#       'url': 'https://www.googletagmanager.com',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'queryString': [],
#       'headersSize': 0,
#       'bodySize': 0,
#       'comment': ''},
#      'response': {'status': 0,
#       'statusText': '',
#       'httpVersion': 'unknown',
#       'cookies': [],
#       'headers': [],
#       'content': {'size': 0, 'mimeType': '', 'comment': ''},
#       'redirectURL': '',
#       'headersSize': -1,
#       'bodySize': -1,
#       'comment': '',
#       '_error': 'Unable to connect to host'},
#      'cache': {},
#      'timings': {'comment': '',
#       'blocked': 0,
#       'dns': 0,
#       'connect': 0,
#       'send': 0,
#       'wait': 0,
#       'receive': 0,
#       'ssl': -1},
#      'serverIPAddress': '0.0.0.0',
#      'comment': '',
#      'time': 1},
#     {'pageref': 'low',
#      'startedDateTime': '2020-10-01T14:35:37.956+05:30',
#      'request': {'method': 'GET',
#       'url': 'https://mp4.sh/embed/6a190390b36d?x=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJkYXRhIjp7ImlzIjowLCJpcCI6IjE1Ny40NC4xNTQuMTE1Iiwic2x1ZyI6ImRlY2EtZGVuY2UtZHViLWVwaXNvZGUtNSIsInJlc3VtZSI6bnVsbH19.df5sIsrINqakov4TLh0pzVHFinkHsQPQ2Pen5c1nnNU',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'queryString': [{'name': 'x',
#         'value': 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJkYXRhIjp7ImlzIjowLCJpcCI6IjE1Ny40NC4xNTQuMTE1Iiwic2x1ZyI6ImRlY2EtZGVuY2UtZHViLWVwaXNvZGUtNSIsInJlc3VtZSI6bnVsbH19.df5sIsrINqakov4TLh0pzVHFinkHsQPQ2Pen5c1nnNU'}],
#       'headersSize': 1159,
#       'bodySize': 0,
#       'comment': ''},
#      'response': {'status': 200,
#       'statusText': 'OK',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'content': {'size': 0,
#        'mimeType': 'text/html; charset=UTF-8',
#        'comment': ''},
#       'redirectURL': '',
#       'headersSize': 978,
#       'bodySize': 4323,
#       'comment': ''},
#      'cache': {},
#      'timings': {'comment': '',
#       'blocked': -1,
#       'dns': -1,
#       'connect': -1,
#       'send': 0,
#       'wait': 553,
#       'receive': 1,
#       'ssl': -1},
#      'serverIPAddress': '172.67.143.85',
#      'comment': '',
#      'time': 555},
#     {'pageref': 'low',
#      'startedDateTime': '2020-10-01T14:35:37.992+05:30',
#      'request': {'method': 'GET',
#       'url': 'https://comments.otaku.cafe/public/app?content_id=da_202156&content_url=aHR0cHM6Ly93dzUuZHViYmVkYW5pbWUubmV0L2VwaXNvZGUvMjAyMTU2LWRlY2EtZGVuY2UtZXBpc29kZS01LWVuZ2xpc2gtZHVi&access_domain=d3c1LmR1YmJlZGFuaW1lLm5ldA==&',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'queryString': [{'name': 'content_id', 'value': 'da_202156'},
#        {'name': 'content_url',
#         'value': 'aHR0cHM6Ly93dzUuZHViYmVkYW5pbWUubmV0L2VwaXNvZGUvMjAyMTU2LWRlY2EtZGVuY2UtZXBpc29kZS01LWVuZ2xpc2gtZHVi'},
#        {'name': 'access_domain', 'value': 'd3c1LmR1YmJlZGFuaW1lLm5ldA=='}],
#       'headersSize': 786,
#       'bodySize': 0,
#       'comment': ''},
#      'response': {'status': 200,
#       'statusText': 'OK',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'content': {'size': 0,
#        'mimeType': 'text/html; charset=UTF-8',
#        'comment': ''},
#       'redirectURL': '',
#       'headersSize': 1116,
#       'bodySize': 1740,
#       'comment': ''},
#      'cache': {},
#      'timings': {'comment': '',
#       'blocked': -1,
#       'dns': -1,
#       'connect': -1,
#       'send': 0,
#       'wait': 327,
#       'receive': 0,
#       'ssl': -1},
#      'serverIPAddress': '104.18.38.170',
#      'comment': '',
#      'time': 328},
#     {'pageref': 'low',
#      'startedDateTime': '2020-10-01T14:35:38.258+05:30',
#      'request': {'method': 'GET',
#       'url': 'https://vid.xngine.com/api/episode/deca-dence-dub-episode-5',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'queryString': [],
#       'headersSize': 510,
#       'bodySize': 0,
#       'comment': ''},
#      'response': {'status': 403,
#       'statusText': 'Forbidden',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'content': {'size': 0,
#        'mimeType': 'text/html; charset=UTF-8',
#        'comment': ''},
#       'redirectURL': '',
#       'headersSize': 926,
#       'bodySize': 5142,
#       'comment': ''},
#      'cache': {},
#      'timings': {'comment': '',
#       'blocked': 0,
#       'dns': 118,
#       'connect': 301,
#       'send': 0,
#       'wait': 102,
#       'receive': 2,
#       'ssl': 211},
#      'serverIPAddress': '104.24.98.55',
#      'comment': '',
#      'time': 525},
#     {'pageref': 'low',
#      'startedDateTime': '2020-10-01T14:35:38.382+05:30',
#      'request': {'method': 'GET',
#       'url': 'https://comments.otaku.cafe/public/css/font-awesome.min.css',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'queryString': [],
#       'headersSize': 633,
#       'bodySize': 0,
#       'comment': ''},
#      'response': {'status': 200,
#       'statusText': 'OK',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'content': {'size': 0, 'mimeType': 'text/css', 'comment': ''},
#       'redirectURL': '',
#       'headersSize': 873,
#       'bodySize': 6663,
#       'comment': ''},
#      'cache': {},
#      'timings': {'comment': '',
#       'blocked': -1,
#       'dns': -1,
#       'connect': -1,
#       'send': 0,
#       'wait': 101,
#       'receive': 4,
#       'ssl': -1},
#      'serverIPAddress': '104.18.38.170',
#      'comment': '',
#      'time': 106},
#     {'pageref': 'low',
#      'startedDateTime': '2020-10-01T14:35:38.491+05:30',
#      'request': {'method': 'GET',
#       'url': 'https://comments.otaku.cafe/public/themes/Envato/main.css',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'queryString': [],
#       'headersSize': 631,
#       'bodySize': 0,
#       'comment': ''},
#      'response': {'status': 200,
#       'statusText': 'OK',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'content': {'size': 0, 'mimeType': 'text/css', 'comment': ''},
#       'redirectURL': '',
#       'headersSize': 889,
#       'bodySize': 3642,
#       'comment': ''},
#      'cache': {},
#      'timings': {'comment': '',
#       'blocked': -1,
#       'dns': -1,
#       'connect': -1,
#       'send': 0,
#       'wait': 100,
#       'receive': 3,
#       'ssl': -1},
#      'serverIPAddress': '172.67.182.146',
#      'comment': '',
#      'time': 103},
#     {'pageref': 'low',
#      'startedDateTime': '2020-10-01T14:35:38.554+05:30',
#      'request': {'method': 'GET',
#       'url': 'https://mp4.sh/css/video-js.min.css',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'queryString': [],
#       'headersSize': 996,
#       'bodySize': 0,
#       'comment': ''},
#      'response': {'status': 200,
#       'statusText': 'OK',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'content': {'size': 0, 'mimeType': 'text/css', 'comment': ''},
#       'redirectURL': '',
#       'headersSize': 852,
#       'bodySize': 9294,
#       'comment': ''},
#      'cache': {},
#      'timings': {'comment': '',
#       'blocked': -1,
#       'dns': -1,
#       'connect': -1,
#       'send': 0,
#       'wait': 129,
#       'receive': 7,
#       'ssl': -1},
#      'serverIPAddress': '172.67.143.85',
#      'comment': '',
#      'time': 136},
#     {'pageref': 'low',
#      'startedDateTime': '2020-10-01T14:35:38.555+05:30',
#      'request': {'method': 'GET',
#       'url': 'https://mp4.sh/css/videojs-mobile-ui.min.css',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'queryString': [],
#       'headersSize': 1005,
#       'bodySize': 0,
#       'comment': ''},
#      'response': {'status': 200,
#       'statusText': 'OK',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'content': {'size': 0, 'mimeType': 'text/css', 'comment': ''},
#       'redirectURL': '',
#       'headersSize': 851,
#       'bodySize': 805,
#       'comment': ''},
#      'cache': {},
#      'timings': {'comment': '',
#       'blocked': -1,
#       'dns': -1,
#       'connect': -1,
#       'send': 0,
#       'wait': 142,
#       'receive': 0,
#       'ssl': -1},
#      'serverIPAddress': '172.67.143.85',
#      'comment': '',
#      'time': 142},
#     {'pageref': 'low',
#      'startedDateTime': '2020-10-01T14:35:38.555+05:30',
#      'request': {'method': 'GET',
#       'url': 'https://mp4.sh/css/vjs.css',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'queryString': [],
#       'headersSize': 987,
#       'bodySize': 0,
#       'comment': ''},
#      'response': {'status': 200,
#       'statusText': 'OK',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'content': {'size': 0, 'mimeType': 'text/css', 'comment': ''},
#       'redirectURL': '',
#       'headersSize': 896,
#       'bodySize': 1282,
#       'comment': ''},
#      'cache': {},
#      'timings': {'comment': '',
#       'blocked': -1,
#       'dns': -1,
#       'connect': -1,
#       'send': 0,
#       'wait': 113,
#       'receive': 15,
#       'ssl': -1},
#      'serverIPAddress': '172.67.143.85',
#      'comment': '',
#      'time': 128},
#     {'pageref': 'low',
#      'startedDateTime': '2020-10-01T14:35:38.597+05:30',
#      'request': {'method': 'GET',
#       'url': 'https://comments.otaku.cafe/public/images/thumbs/avatars-default-s.jpg',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'queryString': [],
#       'headersSize': 665,
#       'bodySize': 0,
#       'comment': ''},
#      'response': {'status': 200,
#       'statusText': 'OK',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'content': {'size': 0, 'mimeType': 'image/jpeg', 'comment': ''},
#       'redirectURL': '',
#       'headersSize': 861,
#       'bodySize': 1290,
#       'comment': ''},
#      'cache': {},
#      'timings': {'comment': '',
#       'blocked': -1,
#       'dns': -1,
#       'connect': -1,
#       'send': 0,
#       'wait': 100,
#       'receive': 0,
#       'ssl': -1},
#      'serverIPAddress': '172.67.182.146',
#      'comment': '',
#      'time': 100},
#     {'pageref': 'low',
#      'startedDateTime': '2020-10-01T14:35:38.632+05:30',
#      'request': {'method': 'GET',
#       'url': 'https://ajax.cloudflare.com/cdn-cgi/scripts/7089c43e/cloudflare-static/rocket-loader.min.js',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'queryString': [],
#       'headersSize': 650,
#       'bodySize': 0,
#       'comment': ''},
#      'response': {'status': 200,
#       'statusText': 'OK',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'content': {'size': 0,
# ...
#       'headers': [],
#       'queryString': [],
#       'headersSize': 631,
#       'bodySize': 0,
#       'comment': ''},
#      'response': {'status': 200,
#       'statusText': 'OK',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'content': {'size': 0, 'mimeType': 'text/javascript', 'comment': ''},
#       'redirectURL': '',
#       'headersSize': 652,
#       'bodySize': 136974,
#       'comment': ''},
#      'cache': {},
#      'timings': {'comment': '',
#       'blocked': -1,
#       'dns': -1,
#       'connect': -1,
#       'send': 0,
#       'wait': 73,
#       'receive': 199,
#       'ssl': -1},
#      'serverIPAddress': '172.217.163.195',
#      'comment': '',
#      'time': 272},
#     {'pageref': 'low',
#      'startedDateTime': '2020-10-01T14:35:39.652+05:30',
#      'request': {'method': 'GET',
#       'url': 'https://vjs.zencdn.net/7.4.1/video.min.js',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'queryString': [],
#       'headersSize': 617,
#       'bodySize': 0,
#       'comment': ''},
#      'response': {'status': 200,
#       'statusText': 'OK',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'content': {'size': 0,
#        'mimeType': 'application/javascript; charset=utf-8',
#        'comment': ''},
#       'redirectURL': '',
#       'headersSize': 455,
#       'bodySize': 135022,
#       'comment': ''},
#      'cache': {},
#      'timings': {'comment': '',
#       'blocked': -1,
#       'dns': -1,
#       'connect': -1,
#       'send': 0,
#       'wait': 141,
#       'receive': 234,
#       'ssl': -1},
#      'serverIPAddress': '151.101.158.217',
#      'comment': '',
#      'time': 376},
#     {'pageref': 'low',
#      'startedDateTime': '2020-10-01T14:35:39.859+05:30',
#      'request': {'method': 'GET',
#       'url': 'https://www.google.com/js/bg/KY8PCQen8i8DcjnCV2aLZanzxLrHczPX8AxOogRZAks.js',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'queryString': [],
#       'headersSize': 812,
#       'bodySize': 0,
#       'comment': ''},
#      'response': {'status': 200,
#       'statusText': 'OK',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'content': {'size': 0, 'mimeType': 'text/javascript', 'comment': ''},
#       'redirectURL': '',
#       'headersSize': 617,
#       'bodySize': 6046,
#       'comment': ''},
#      'cache': {},
#      'timings': {'comment': '',
#       'blocked': -1,
#       'dns': -1,
#       'connect': -1,
#       'send': 0,
#       'wait': 89,
#       'receive': 11,
#       'ssl': -1},
#      'serverIPAddress': '172.217.163.68',
#      'comment': '',
#      'time': 101},
#     {'pageref': 'low',
#      'startedDateTime': '2020-10-01T14:35:39.888+05:30',
#      'request': {'method': 'GET',
#       'url': 'https://mp4.sh/js/addbutton.js?v=1.1',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'queryString': [{'name': 'v', 'value': '1.1'}],
#       'headersSize': 983,
#       'bodySize': 0,
#       'comment': ''},
#      'response': {'status': 200,
#       'statusText': 'OK',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'content': {'size': 0,
#        'mimeType': 'application/javascript; charset=utf-8',
#        'comment': ''},
#       'redirectURL': '',
#       'headersSize': 896,
#       'bodySize': 997,
#       'comment': ''},
#      'cache': {},
#      'timings': {'comment': '',
#       'blocked': -1,
#       'dns': -1,
#       'connect': -1,
#       'send': 0,
#       'wait': 127,
#       'receive': 0,
#       'ssl': -1},
#      'serverIPAddress': '172.67.143.85',
#      'comment': '',
#      'time': 128},
#     {'pageref': 'low',
#      'startedDateTime': '2020-10-01T14:35:39.887+05:30',
#      'request': {'method': 'CONNECT',
#       'url': 'https://www.googletagmanager.com',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'queryString': [],
#       'headersSize': 0,
#       'bodySize': 0,
#       'comment': ''},
#      'response': {'status': 0,
#       'statusText': '',
#       'httpVersion': 'unknown',
#       'cookies': [],
#       'headers': [],
#       'content': {'size': 0, 'mimeType': '', 'comment': ''},
#       'redirectURL': '',
#       'headersSize': -1,
#       'bodySize': -1,
#       'comment': '',
#       '_error': 'Unable to connect to host'},
#      'cache': {},
#      'timings': {'comment': '',
#       'blocked': 0,
#       'dns': 0,
#       'connect': 1,
#       'send': 0,
#       'wait': 0,
#       'receive': 0,
#       'ssl': -1},
#      'serverIPAddress': '0.0.0.0',
#      'comment': '',
#      'time': 1},
#     {'pageref': 'low',
#      'startedDateTime': '2020-10-01T14:35:39.961+05:30',
#      'request': {'method': 'GET',
#       'url': 'https://www.google.com/recaptcha/api2/webworker.js?hl=en&v=Y5tQ3lKwn1XL5hGgLz1kR4-1',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'queryString': [{'name': 'hl', 'value': 'en'},
#        {'name': 'v', 'value': 'Y5tQ3lKwn1XL5hGgLz1kR4-1'}],
#       'headersSize': 824,
#       'bodySize': 0,
#       'comment': ''},
#      'response': {'status': 200,
#       'statusText': 'OK',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'content': {'size': 0,
#        'mimeType': 'text/javascript; charset=UTF-8',
#        'comment': ''},
#       'redirectURL': '',
#       'headersSize': 620,
#       'bodySize': 112,
#       'comment': ''},
#      'cache': {},
#      'timings': {'comment': '',
#       'blocked': -1,
#       'dns': -1,
#       'connect': -1,
#       'send': 0,
#       'wait': 162,
#       'receive': 0,
#       'ssl': -1},
#      'serverIPAddress': '172.217.166.100',
#      'comment': '',
#      'time': 162},
#     {'pageref': 'low',
#      'startedDateTime': '2020-10-01T14:35:39.984+05:30',
#      'request': {'method': 'GET',
#       'url': 'https://mp4.sh/js/volume.js',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'queryString': [],
#       'headersSize': 974,
#       'bodySize': 0,
#       'comment': ''},
#      'response': {'status': 200,
#       'statusText': 'OK',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'content': {'size': 0,
#        'mimeType': 'application/javascript; charset=utf-8',
#        'comment': ''},
#       'redirectURL': '',
#       'headersSize': 925,
#       'bodySize': 1116,
#       'comment': ''},
#      'cache': {},
#      'timings': {'comment': '',
#       'blocked': -1,
#       'dns': -1,
#       'connect': -1,
#       'send': 0,
#       'wait': 108,
#       'receive': 0,
#       'ssl': -1},
#      'serverIPAddress': '172.67.143.85',
#      'comment': '',
#      'time': 109},
#     {'pageref': 'low',
#      'startedDateTime': '2020-10-01T14:35:40.134+05:30',
#      'request': {'method': 'GET',
#       'url': 'https://www.gstatic.com/recaptcha/releases/Y5tQ3lKwn1XL5hGgLz1kR4-1/recaptcha__en.js',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'queryString': [],
#       'headersSize': 510,
#       'bodySize': 0,
#       'comment': ''},
#      'response': {'status': 200,
#       'statusText': 'OK',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'content': {'size': 0, 'mimeType': 'text/javascript', 'comment': ''},
#       'redirectURL': '',
#       'headersSize': 652,
#       'bodySize': 136974,
#       'comment': ''},
#      'cache': {},
#      'timings': {'comment': '',
#       'blocked': -1,
#       'dns': -1,
#       'connect': -1,
#       'send': 0,
#       'wait': 54,
#       'receive': 308,
#       'ssl': -1},
#      'serverIPAddress': '172.217.163.195',
#      'comment': '',
#      'time': 362},
#     {'pageref': 'low',
#      'startedDateTime': '2020-10-01T14:35:40.196+05:30',
#      'request': {'method': 'GET',
#       'url': 'https://cdn.sc.gl/videojs-hotkeys/latest/videojs.hotkeys.min.js',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'queryString': [],
#       'headersSize': 639,
#       'bodySize': 0,
#       'comment': ''},
#      'response': {'status': 200,
#       'statusText': 'OK',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'content': {'size': 0,
#        'mimeType': 'application/javascript',
#        'comment': ''},
#       'redirectURL': '',
#       'headersSize': 871,
#       'bodySize': 1652,
#       'comment': ''},
#      'cache': {},
#      'timings': {'comment': '',
#       'blocked': 0,
#       'dns': 98,
#       'connect': 210,
#       'send': 0,
#       'wait': 323,
#       'receive': 1,
#       'ssl': 119},
#      'serverIPAddress': '104.28.7.84',
#      'comment': '',
#      'time': 634},
#     {'pageref': 'low',
#      'startedDateTime': '2020-10-01T14:35:40.211+05:30',
#      'request': {'method': 'GET',
#       'url': 'https://cdn.jsdelivr.net/npm/videojs-mobile-ui@0.4.1/dist/videojs-mobile-ui.min.js',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'queryString': [],
#       'headersSize': 658,
#       'bodySize': 0,
#       'comment': ''},
#      'response': {'status': 200,
#       'statusText': 'OK',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'content': {'size': 0,
#        'mimeType': 'application/javascript; charset=utf-8',
#        'comment': ''},
#       'redirectURL': '',
#       'headersSize': 623,
#       'bodySize': 1754,
#       'comment': ''},
#      'cache': {},
#      'timings': {'comment': '',
#       'blocked': 0,
#       'dns': 109,
#       'connect': 221,
#       'send': 0,
#       'wait': 286,
#       'receive': 0,
#       'ssl': 124},
#      'serverIPAddress': '151.101.158.109',
#      'comment': '',
#      'time': 617},
#     {'pageref': 'low',
#      'startedDateTime': '2020-10-01T14:35:40.524+05:30',
#      'request': {'method': 'GET',
#       'url': 'https://cdn.animeapi.com/images/1/6a190390b36d.jpg',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'queryString': [],
#       'headersSize': 661,
#       'bodySize': 0,
#       'comment': ''},
#      'response': {'status': 200,
#       'statusText': 'OK',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'content': {'size': 0, 'mimeType': 'image/jpeg', 'comment': ''},
#       'redirectURL': '',
#       'headersSize': 911,
#       'bodySize': 41979,
#       'comment': ''},
#      'cache': {},
#      'timings': {'comment': '',
#       'blocked': 0,
#       'dns': 221,
#       'connect': 410,
#       'send': 0,
#       'wait': 147,
#       'receive': 93,
#       'ssl': 337},
#      'serverIPAddress': '172.67.147.77',
#      'comment': '',
#      'time': 873},
#     {'pageref': 'low',
#      'startedDateTime': '2020-10-01T14:35:40.539+05:30',
#      'request': {'method': 'CONNECT',
#       'url': 'https://whos.amung.us',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'queryString': [],
#       'headersSize': 0,
#       'bodySize': 0,
#       'comment': ''},
#      'response': {'status': 0,
#       'statusText': '',
#       'httpVersion': 'unknown',
#       'cookies': [],
#       'headers': [],
#       'content': {'size': 0, 'mimeType': '', 'comment': ''},
#       'redirectURL': '',
#       'headersSize': -1,
#       'bodySize': -1,
#       'comment': '',
#       '_error': 'Unable to connect to host'},
#      'cache': {},
#      'timings': {'comment': '',
#       'blocked': 0,
#       'dns': 7,
#       'connect': 0,
#       'send': 0,
#       'wait': 0,
#       'receive': 0,
#       'ssl': -1},
#      'serverIPAddress': '0.0.0.0',
#      'comment': '',
#      'time': 8},
#     {'pageref': 'low',
#      'startedDateTime': '2020-10-01T14:35:40.594+05:30',
#      'request': {'method': 'POST',
#       'url': 'https://www.google.com/recaptcha/api2/reload?k=6LfkMNAZAAAAAGNp2RRHAgiUbfTpAhKT_tOTLwJ7',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'queryString': [{'name': 'k',
#         'value': '6LfkMNAZAAAAAGNp2RRHAgiUbfTpAhKT_tOTLwJ7'}],
#       'headersSize': 916,
#       'bodySize': 5338,
#       'comment': ''},
#      'response': {'status': 200,
#       'statusText': 'OK',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'content': {'size': 0,
#        'mimeType': 'application/json; charset=utf-8',
#        'comment': ''},
#       'redirectURL': '',
#       'headersSize': 619,
#       'bodySize': 6732,
#       'comment': ''},
#      'cache': {},
#      'timings': {'comment': '',
#       'blocked': -1,
#       'dns': -1,
#       'connect': -1,
#       'send': 0,
#       'wait': 253,
#       'receive': 14,
#       'ssl': -1},
#      'serverIPAddress': '172.217.166.100',
#      'comment': '',
#      'time': 267},
#     {'pageref': 'low',
#      'startedDateTime': '2020-10-01T14:35:40.851+05:30',
#      'request': {'method': 'GET',
#       'url': 'https://actressact.com/47/55/d0/4755d0defc2e57c739e469d831410255.js',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'queryString': [],
#       'headersSize': 643,
#       'bodySize': 0,
#       'comment': ''},
#      'response': {'status': 200,
#       'statusText': 'OK',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'content': {'size': 0,
#        'mimeType': 'application/javascript',
#        'comment': ''},
#       'redirectURL': '',
#       'headersSize': 424,
#       'bodySize': 17191,
#       'comment': ''},
#      'cache': {},
#      'timings': {'comment': '',
#       'blocked': 0,
#       'dns': 6,
#       'connect': 955,
#       'send': 0,
#       'wait': 480,
#       'receive': 319,
#       'ssl': 678},
#      'serverIPAddress': '192.243.59.12',
#      'comment': '',
#      'time': 1761},
#     {'pageref': 'low',
#      'startedDateTime': '2020-10-01T14:35:41.673+05:30',
#      'request': {'method': 'GET',
#       'url': 'https://ie8eamus.com/sfp.js',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'queryString': [],
#       'headersSize': 603,
#       'bodySize': 0,
#       'comment': ''},
#      'response': {'status': 200,
#       'statusText': 'OK',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'content': {'size': 0,
#        'mimeType': 'application/javascript; charset=utf-8',
#        'comment': ''},
#       'redirectURL': '',
#       'headersSize': 1021,
#       'bodySize': 21148,
#       'comment': ''},
#      'cache': {},
#      'timings': {'comment': '',
#       'blocked': -1,
#       'dns': -1,
#       'connect': -1,
#       'send': 0,
#       'wait': 221,
#       'receive': 26,
#       'ssl': -1},
#      'serverIPAddress': '172.64.167.37',
#      'comment': '',
#      'time': 247},
#     {'pageref': 'low',
#      'startedDateTime': '2020-10-01T14:35:41.686+05:30',
#      'request': {'method': 'POST',
#       'url': 'https://mp4.sh/v/6a190390b36d',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'queryString': [],
#       'headersSize': 1067,
#       'bodySize': 269,
#       'comment': ''},
#      'response': {'status': 200,
#       'statusText': 'OK',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'content': {'size': 0, 'mimeType': 'application/json', 'comment': ''},
#       'redirectURL': '',
#       'headersSize': 729,
#       'bodySize': 103,
#       'comment': ''},
#      'cache': {},
#      'timings': {'comment': '',
#       'blocked': -1,
#       'dns': -1,
#       'connect': -1,
#       'send': 0,
#       'wait': 352,
#       'receive': 0,
#       'ssl': -1},
#      'serverIPAddress': '172.67.143.85',
#      'comment': '',
#      'time': 353},
#     {'pageref': 'low',
#      'startedDateTime': '2020-10-01T14:35:41.763+05:30',
#      'request': {'method': 'GET',
#       'url': 'https://mp4.sh/images/ripple.svg',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'queryString': [],
#       'headersSize': 1014,
#       'bodySize': 0,
#       'comment': ''},
#      'response': {'status': 200,
#       'statusText': 'OK',
#       'httpVersion': 'HTTP/1.1',
#       'cookies': [],
#       'headers': [],
#       'content': {'size': 0, 'mimeType': 'image/svg+xml', 'comment': ''},
#       'redirectURL': '',
#       'headersSize': 856,
#       'bodySize': 337,
#       'comment': ''},
#      'cache': {},
#      'timings': {'comment': '',
#       'blocked': -1,
#       'dns': -1,
#       'connect': -1,
#       'send': 0,
#       'wait': 130,
#       'receive': 0,
#       'ssl': -1},
#      'serverIPAddress': '172.67.143.85',
#      'comment': '',
#      'time': 130}],
#    'comment': ''}})

# %%
browser.get(url)

# %%
print(proxy.har)
# Out:
# {'log': {'version': '1.2', 'creator': {'name': 'BrowserMob Proxy', 'version': '2.1.4', 'comment': ''}, 'pages': [{'id': 'low', 'startedDateTime': '2020-10-01T14:35:42.603+05:30', 'title': 'low', 'pageTimings': {'comment': ''}, 'comment': ''}], 'entries': [{'pageref': 'low', 'startedDateTime': '2020-10-01T14:35:42.722+05:30', 'request': {'method': 'GET', 'url': 'https://amuletlatemanagement.com/93/0e/98/930e98122e1841c8112ab29dda9e4a67.js', 'httpVersion': 'HTTP/1.1', 'cookies': [], 'headers': [], 'queryString': [], 'headersSize': 653, 'bodySize': 0, 'comment': ''}, 'response': {'status': 200, 'statusText': 'OK', 'httpVersion': 'HTTP/1.1', 'cookies': [], 'headers': [], 'content': {'size': 0, 'mimeType': 'application/javascript', 'comment': ''}, 'redirectURL': '', 'headersSize': 424, 'bodySize': 8071, 'comment': ''}, 'cache': {}, 'timings': {'comment': '', 'blocked': 0, 'dns': 88, 'connect': 959, 'send': 0, 'wait': 285, 'receive': 0, 'ssl': 704}, 'serverIPAddress': '192.243.59.12', 'comment': '', 'time': 1333}, {'pageref': 'low', 'startedDateTime': '2020-10-01T14:35:42.833+05:30', 'request': {'method': 'GET', 'url': 'https://s1.mp4.sh/d/6a190390b36d.mp4?st=frASkznIkLW8DRWsRAAqVA&e=1601629541', 'httpVersion': 'HTTP/1.1', 'cookies': [], 'headers': [], 'queryString': [{'name': 'st', 'value': 'frASkznIkLW8DRWsRAAqVA'}, {'name': 'e', 'value': '1601629541'}], 'headersSize': 949, 'bodySize': 0, 'comment': ''}, 'response': {'status': 206, 'statusText': 'Partial Content', 'httpVersion': 'HTTP/1.1', 'cookies': [], 'headers': [], 'content': {'size': 0, 'mimeType': 'video/mp4', 'comment': ''}, 'redirectURL': '', 'headersSize': 294, 'bodySize': -1, 'comment': ''}, 'cache': {}, 'timings': {'comment': '', 'blocked': 0, 'dns': 15, 'connect': 666, 'send': 0, 'wait': 433, 'receive': 5850, 'ssl': 462}, 'serverIPAddress': '217.182.198.170', 'comment': '', 'time': 6966}, {'pageref': 'low', 'startedDateTime': '2020-10-01T14:35:42.834+05:30', 'request': {'method': 'GET', 'url': 'https://d24ak3f2b.top/advertisers.js', 'httpVersion': 'HTTP/1.1', 'cookies': [], 'headers': [], 'queryString': [], 'headersSize': 612, 'bodySize': 0, 'comment': ''}, 'response': {'status': 200, 'statusText': 'OK', 'httpVersion': 'HTTP/1.1', 'cookies': [], 'headers': [], 'content': {'size': 0, 'mimeType': 'application/javascript', 'comment': ''}, 'redirectURL': '', 'headersSize': 161, 'bodySize': 0, 'comment': ''}, 'cache': {}, 'timings': {'comment': '', 'blocked': 0, 'dns': 12, 'connect': 941, 'send': 0, 'wait': 310, 'receive': 0, 'ssl': 614}, 'serverIPAddress': '142.0.204.220', 'comment': '', 'time': 1264}, {'pageref': 'low', 'startedDateTime': '2020-10-01T14:35:43.024+05:30', 'request': {'method': 'CONNECT', 'url': 'https://r.remarketingpixel.com', 'httpVersion': 'HTTP/1.1', 'cookies': [], 'headers': [], 'queryString': [], 'headersSize': 0, 'bodySize': 0, 'comment': ''}, 'response': {'status': 0, 'statusText': '', 'httpVersion': 'unknown', 'cookies': [], 'headers': [], 'content': {'size': 0, 'mimeType': '', 'comment': ''}, 'redirectURL': '', 'headersSize': -1, 'bodySize': -1, 'comment': '', '_error': 'Unable to connect to host'}, 'cache': {}, 'timings': {'comment': '', 'blocked': 0, 'dns': 10, 'connect': 1, 'send': 0, 'wait': 0, 'receive': 0, 'ssl': -1}, 'serverIPAddress': '0.0.0.0', 'comment': '', 'time': 12}, {'pageref': 'low', 'startedDateTime': '2020-10-01T14:35:44.664+05:30', 'request': {'method': 'GET', 'url': 'https://dentalsadness.com/sbar.json?key=930e98122e1841c8112ab29dda9e4a67', 'httpVersion': 'HTTP/1.1', 'cookies': [], 'headers': [], 'queryString': [{'name': 'key', 'value': '930e98122e1841c8112ab29dda9e4a67'}], 'headersSize': 668, 'bodySize': 0, 'comment': ''}, 'response': {'status': 200, 'statusText': 'OK', 'httpVersion': 'HTTP/1.1', 'cookies': [], 'headers': [], 'content': {'size': 0, 'mimeType': 'text/plain; charset=utf-8', 'comment': ''}, 'redirectURL': '', 'headersSize': 929, 'bodySize': 1359, 'comment': ''}, 'cache': {}, 'timings': {'comment': '', 'blocked' ...

# %%
with open('new_har.har', 'w')  as har_file:
    har_file.seek(0)
    json.dump(proxy.har, har_file)

# %%
from haralyzer import HarPage
from haralyzer import HarParser

# %%
#with open('new_har.har', 'r') as f:
har_page = HarPage("low", har_data=proxy.har)

# %%
entries = har_page.filter_entries(content_type='video.*',request_type="GET" , status_code='2.*')

# %%
entries[0]['request']['url']
# Out:
# 'https://s1.mp4.sh/d/6a190390b36d.mp4?st=frASkznIkLW8DRWsRAAqVA&e=1601629541'
